# %% [markdown]
# # ***Demo: ModelParallel training with Amazon SageMaker***

# %%
# !pip install sagemaker --upgrade -q
# !pip install ipywidgets -q
# !wget https://raw.githubusercontent.com/awslabs/amazon-sagemaker-examples/master/advanced_functionality/tensorflow_bring_your_own/utils/generate_cifar10_tfrecords.py
# !python generate_cifar10_tfrecords.py --data-dir cifar10

# %% [markdown]
# **Step 1:** Import essentials packages, start a sagemaker session and specify the bucket name you created in the pre-requsites section of this workshop.

# %%
import os
import boto3
import time
import numpy as np
import sagemaker

sess = boto3.Session()
sm   = sess.client('sagemaker')
sagemaker_session = sagemaker.Session()
role = sagemaker.get_execution_role()

bucket_name    = sagemaker_session.default_bucket()
jobs_folder    = 'jobs'
dataset_folder = 'datasets'

# %% [markdown]
# #### Upload dataset if it doesn't exist

# %%
# datasets = sagemaker_session.upload_data(path='cifar10', key_prefix=f'{dataset_folder}/cifar10-dataset')
# datasets

#If dataset already exists
datasets = f's3://{bucket_name}/{dataset_folder}/cifar10-dataset'
datasets
# Out:
# 's3://sagemaker-us-west-2-453691756499/datasets/cifar10-dataset'

# %%
instance_type = 'ml.p3.16xlarge'
instance_count = 1

distribution={
              "smdistributed": {
                  "modelparallel": {
                      "enabled":True,
                      "parameters": {
                          "microbatches": 2, 
                          "partitions": 2, 
                          "pipeline": "interleaved", 
                          "optimize": "speed",
                      }
                  }
              },
               "mpi": {
                   "enabled" : True,
                   "processes_per_host" : 2,
                   "custom_mpi_options" : "-verbose -x orte_base_help_aggregate=0 "
               }
              }

# %% [markdown]
# **Step 2:** Specify hyperparameters, instance type and number of instances to distribute training to.

# %%
instance_type_name = f'{instance_type.replace(".","-")}'
job_name   = f'tf-modelparallel-{instance_type_name}-{time.strftime("%Y-%m-%d-%H-%M-%S-%j", time.gmtime())}'
output_path = f's3://{bucket_name}/{jobs_folder}'

metric_definitions = [{'Name': 'Validation Accuracy', 'Regex': 'Validation Accuracy: ([0-9\\.]+)'}]

hyperparameters = {'epochs': 50, 
                   'learning-rate': 0.01,
                   'momentum': 0.95,
                   'weight-decay': 2e-4,
                   'optimizer': 'adam',
                   'batch-size' : 256,
                   'model-type': 'custom'}

# %%
from sagemaker.tensorflow import TensorFlow
smdp_estimator = TensorFlow(entry_point         = 'cifar10-tf2-smmodelparallel.py', 
                           source_dir           = 'code',
                           output_path          = output_path + '/',
                           code_location        = output_path,
                           role                 = role,
                           instance_count       = instance_count,
                           instance_type        = instance_type,
                           framework_version    = '2.4', 
                           py_version           = 'py37',
                           metric_definitions   = metric_definitions,
                           hyperparameters      = hyperparameters,
                           distribution         = distribution)

# %% [markdown]
# **Step 4:** Specify dataset locations in Amazon S3 and then call the fit function.

# %%
smdp_estimator.fit({'train': datasets,
                    'validation': datasets,
                    'eval': datasets}, 
                  job_name=job_name, wait=True)
# Out:
# 2021-04-18 18:58:01 Starting - Starting the training job...
# 2021-04-18 18:58:23 Starting - Launching requested ML instancesProfilerReport-1618772280: InProgress
# .........
# 2021-04-18 18:59:44 Starting - Preparing the instances for training............
# 2021-04-18 19:01:50 Downloading - Downloading input data
# 2021-04-18 19:01:50 Training - Downloading the training image............
# 2021-04-18 19:03:47 Training - Training image download completed. Training in progress.2021-04-18 19:03:47.592437: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-04-18 19:03:47.597867: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2021-04-18 19:03:47.692157: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-04-18 19:03:47.791805: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2021-04-18 19:03:51,392 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2021-04-18 19:03:51,848 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /usr/local/bin/python3.7 -m pip install -r requirements.txt
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (7.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (1.19.5)
# 2021-04-18 19:03:53,740 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2021-04-18 19:03:53,740 sagemaker-training-toolkit INFO     Creating SSH daemon.
# 2021-04-18 19:03:53,747 sagemaker-training-toolkit INFO     Waiting for MPI workers to establish their SSH connections
# 2021-04-18 19:03:53,750 sagemaker-training-toolkit INFO     Env Hosts: ['algo-1'] Hosts: ['algo-1:2'] process_per_hosts: 2 num_processes: 2
# 2021-04-18 19:03:53,752 sagemaker-training-toolkit INFO     Network interface name: eth0
# 2021-04-18 19:03:53,837 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {
#         "sagemaker_mpi_num_of_processes_per_host": 2,
#         "sagemaker_distributed_dataparallel_enabled": false,
#         "sagemaker_mpi_custom_mpi_options": "-verbose -x orte_base_help_aggregate=0 ",
#         "sagemaker_mpi_enabled": true,
#         "sagemaker_instance_type": "ml.p3.16xlarge"
#     },
#     "channel_input_dirs": {
#         "eval": "/opt/ml/input/data/eval",
#         "validation": "/opt/ml/input/data/validation",
#         "train": "/opt/ml/input/data/train"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "model-type": "custom",
#         "momentum": 0.95,
#         "batch-size": 256,
#         "learning-rate": 0.01,
#         "optimizer": "adam",
#         "model_dir": "/opt/ml/model",
#         "weight-decay": 0.0002,
#         "epochs": 50,
#         "mp_parameters": {
#             "microbatches": 2,
#             "partitions": 2,
#             "pipeline": "interleaved",
#             "optimize": "speed"
#         }
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "eval": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "tf-modelparallel-ml-p3-16xlarge-2021-04-18-18-58-00-108",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-west-2-453691756499/jobs/tf-modelparallel-ml-p3-16xlarge-2021-04-18-18-58-00-108/source/sourcedir.tar.gz",
#     "module_name": "cifar10-tf2-smmodelparallel",
#     "network_interface_name": "eth0",
#     "num_cpus": 64,
#     "num_gpus": 8,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "cifar10-tf2-smmodelparallel.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch-size":256,"epochs":50,"learning-rate":0.01,"model-type":"custom","model_dir":"/opt/ml/model","momentum":0.95,"mp_parameters":{"microbatches":2,"optimize":"speed","partitions":2,"pipeline":"interleaved"},"optimizer":"adam","weight-decay":0.0002}
# SM_USER_ENTRY_POINT=cifar10-tf2-smmodelparallel.py
# SM_FRAMEWORK_PARAMS={"sagemaker_distributed_dataparallel_enabled":false,"sagemaker_instance_type":"ml.p3.16xlarge","sagemaker_mpi_custom_mpi_options":"-verbose -x orte_base_help_aggregate=0 ","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":2}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["eval","train","validation"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=cifar10-tf2-smmodelparallel
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=64
# SM_NUM_GPUS=8
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-west-2-453691756499/jobs/tf-modelparallel-ml-p3-16xlarge-2021-04-18-18-58-00-108/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_distributed_dataparallel_enabled":false,"sagemaker_instance_type":"ml.p3.16xlarge","sagemaker_mpi_custom_mpi_options":"-verbose -x orte_base_help_aggregate=0 ","sagemaker_mpi_enabled":true,"sagemaker_mpi_num_of_processes_per_host":2},"channel_input_dirs":{"eval":"/opt/ml/input/data/eval","train":"/opt/ml/input/data/train","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch-size":256,"epochs":50,"learning-rate":0.01,"model-type":"custom","model_dir":"/opt/ml/model","momentum":0.95,"mp_parameters":{"microbatches":2,"optimize":"speed","partitions":2,"pipeline":"interleaved"},"optimizer":"adam","weight-decay":0.0002},"input_config_dir":"/opt/ml/input/config","input_data_config":{"eval":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"tf-modelparallel-ml-p3-16xlarge-2021-04-18-18-58-00-108","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-west-2-453691756499/jobs/tf-modelparallel-ml-p3-16xlarge-2021-04-18-18-58-00-108/source/sourcedir.tar.gz","module_name":"cifar10-tf2-smmodelparallel","network_interface_name":"eth0","num_cpus":64,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"cifar10-tf2-smmodelparallel.py"}
# SM_USER_ARGS=["--batch-size","256","--epochs","50","--learning-rate","0.01","--model-type","custom","--model_dir","/opt/ml/model","--momentum","0.95","--mp_parameters","microbatches=2,optimize=speed,partitions=2,pipeline=interleaved","--optimizer","adam","--weight-decay","0.0002"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_EVAL=/opt/ml/input/data/eval
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_HP_MODEL-TYPE=custom
# SM_HP_MOMENTUM=0.95
# SM_HP_BATCH-SIZE=256
# SM_HP_LEARNING-RATE=0.01
# SM_HP_OPTIMIZER=adam
# SM_HP_MODEL_DIR=/opt/ml/model
# SM_HP_WEIGHT-DECAY=0.0002
# SM_HP_EPOCHS=50
# SM_HP_MP_PARAMETERS={"microbatches":2,"optimize":"speed","partitions":2,"pipeline":"interleaved"}
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python37.zip:/usr/local/lib/python3.7:/usr/local/lib/python3.7/lib-dynload:/usr/local/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# mpirun --host algo-1:2 -np 2 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -bind-to none -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/usr/local/lib/python3.7/site-packages/gethostname.cpython-37m-x86_64-linux-gnu.so -verbose -x orte_base_help_aggregate=0 -x SM_HOSTS -x SM_NETWORK_INTERFACE_NAME -x SM_HPS -x SM_USER_ENTRY_POINT -x SM_FRAMEWORK_PARAMS -x SM_RESOURCE_CONFIG -x SM_INPUT_DATA_CONFIG -x SM_OUTPUT_DATA_DIR -x SM_CHANNELS -x SM_CURRENT_HOST -x SM_MODULE_NAME -x SM_LOG_LEVEL -x SM_FRAMEWORK_MODULE -x SM_INPUT_DIR -x SM_INPUT_CONFIG_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_NUM_GPUS -x SM_MODEL_DIR -x SM_MODULE_DIR -x SM_TRAINING_ENV -x SM_USER_ARGS -x SM_OUTPUT_INTERMEDIATE_DIR -x SM_CHANNEL_EVAL -x SM_CHANNEL_VALIDATION -x SM_CHANNEL_TRAIN -x SM_HP_MODEL-TYPE -x SM_HP_MOMENTUM -x SM_HP_BATCH-SIZE -x SM_HP_LEARNING-RATE -x SM_HP_OPTIMIZER -x SM_HP_MODEL_DIR -x SM_HP_WEIGHT-DECAY -x SM_HP_EPOCHS -x SM_HP_MP_PARAMETERS -x PYTHONPATH /usr/local/bin/python3.7 -m mpi4py cifar10-tf2-smmodelparallel.py --batch-size 256 --epochs 50 --learning-rate 0.01 --model-type custom --model_dir /opt/ml/model --momentum 0.95 --mp_parameters microbatches=2,optimize=speed,partitions=2,pipeline=interleaved --optimizer adam --weight-decay 0.0002
#
#
#  Data for JOB [21620,1] offset 0 Total slots allocated 2
#
#  ========================   JOB MAP   ========================
#
#  Data for node: ip-10-0-146-164#011Num slots: 2#011Max slots: 0#011Num procs: 2
#  #011Process OMPI jobid: [21620,1] App: 0 Process rank: 0 Bound: N/A
#  #011Process OMPI jobid: [21620,1] App: 0 Process rank: 1 Bound: N/A
#
#  =============================================================
# [1,0]<stdout>:[2021-04-18 19:03:56.591 algo-1:157 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,1]<stdout>:[2021-04-18 19:03:56.591 algo-1:158 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,0]<stdout>:[2021-04-18 19:03:56.667 algo-1:157 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,1]<stdout>:[2021-04-18 19:03:56.667 algo-1:158 INFO profiler_config_parser.py:102] User has disabled profiler.
# [1,0]<stdout>:[2021-04-18 19:04:06.257: I smdistributed/modelparallel/tensorflow/auto.py:383] Total variables in device 0: 20
# [1,0]<stdout>:[2021-04-18 19:04:06.258: I smdistributed/modelparallel/tensorflow/auto.py:383] Total variables in device 1: 20
# [1,0]<stdout>:[2021-04-18 19:04:06.258: I smdistributed/modelparallel/tensorflow/auto.py:387] Total ops in device 0: 69
# [1,0]<stdout>:[2021-04-18 19:04:06.258: I smdistributed/modelparallel/tensorflow/auto.py:387] Total ops in device 1: 91
# [1,0]<stdout>:[2021-04-18 19:04:37.479: I smdistributed/modelparallel/tensorflow/auto.py:383] Total variables in device 0: 20
# [1,0]<stdout>:[2021-04-18 19:04:37.479: I smdistributed/modelparallel/tensorflow/auto.py:383] Total variables in device 1: 20
# [1,0]<stdout>:[2021-04-18 19:04:37.479: I smdistributed/modelparallel/tensorflow/auto.py:387] Total ops in device 0: 56
# [1,0]<stdout>:[2021-04-18 19:04:37.479: I smdistributed/modelparallel/tensorflow/auto.py:387] Total ops in device 1: 64
# [1,1]<stdout>:Epoch: 1, Epoch duration: 0.014308452606201172 sec, Training loss: 2.48020339012146, Training accuracy: 10.048578262329102 Validation Loss: 2.304015636444092, Validation Accuracy: 10.186298370361328
# [1,0]<stdout>:Epoch: 1, Epoch duration: 0.01417088508605957 sec, Training loss: 2.48020339012146, Training accuracy: 10.048578262329102 Validation Loss: 2.304015636444092, Validation Accuracy: 10.186298370361328
# [1,1]<stdout>:Epoch: 2, Epoch duration: 0.014793872833251953 sec, Training loss: 2.3033316135406494, Training accuracy: 9.903345108032227 Validation Loss: 2.3028950691223145, Validation Accuracy: 10.246394157409668
# [1,0]<stdout>:Epoch: 2, Epoch duration: 0.014778614044189453 sec, Training loss: 2.3033316135406494, Training accuracy: 9.903345108032227 Validation Loss: 2.3028950691223145, Validation Accuracy: 10.246394157409668
# [1,1]<stdout>:Epoch: 3, Epoch duration: 0.014589786529541016 sec, Training loss: 2.1473653316497803, Training accuracy: 15.740184783935547 Validation Loss: 2.490636110305786, Validation Accuracy: 15.154247283935547
